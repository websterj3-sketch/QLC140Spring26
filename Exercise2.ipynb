# %% [markdown]
# <a href="https://colab.research.google.com/github/websterj3-sketch/QLC140Spring26/blob/main/Exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages needed for figures generation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# In the next cell we are going to install cartopy before loading it using import

# %%
# !pip install cartopy
import cartopy

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# Create figure on 10 by 5 plane
fig = plt.figure(figsize=(10, 5))
# Add a drawing area and set up the map projection
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
# Draw the coastlines of all the continents and major islands
ax.coastlines()

#Add an arrow saying "We are here" pointing to Charlotte, North Carolina
ax.text(charlotte_lon + 10, charlotte_lat + 10, 'We are here', color='blue', transform=ccrs.PlateCarree(), ha='center', va='center')
ax.annotate('', xy=(charlotte_lon, charlotte_lat), xytext=(charlotte_lon + 10, charlotte_lat + 10), arrowprops=dict(facecolor='blue', arrowstyle='->', connectionstyle='arc3,rad=.2'), transform=ccrs.PlateCarree())

#Add major ocean labels (Atlantic, Pacific, etc.)
ax.text(-40, 30, 'Atlantic Ocean', color='blue', transform=ccrs.PlateCarree(), ha='center', va='center')
ax.text(-120, 0, 'Pacific Ocean', color='blue', transform=ccrs.PlateCarree(), ha='center', va='center')
ax.text(80, -10, 'Indian Ocean', color='blue', transform=ccrs.PlateCarree(), ha='center', va='center')
ax.text(0, -60, 'Southern Ocean', color='blue', transform=ccrs.PlateCarree(), ha='center', va='center')

# Add gridlines with labels
gridlines = ax.gridlines(draw_labels=True, x_inline=False, y_inline=False)
gridlines.top_labels = False
gridlines.right_labels = False

# Add a title to the projection
plt.title('Map of the Earth')
# Display the plot window
plt.show()
